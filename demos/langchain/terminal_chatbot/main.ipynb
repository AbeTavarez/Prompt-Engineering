# %%
# pip install langchain

# %%
# pip install -U langchain-groq

# %%
# from langchain.prompts import HumanMessagePromptTemplate

# %%
# while True:
#   content = input('>>')
#   print(f'You said: {content}')

# %%
import os
from langchain.prompts import PromptTemplate, SystemMessagePromptTemplate
from langchain.chains import LLMChain
from langchain_groq import ChatGroq
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[43], line 3
#       1 import os
#       2 from langchain.prompts import PromptTemplate, SystemMessagePromptTemplate
# ----> 3 from langchain.chains import LLMChain
#       4 from langchain_groq import ChatGroq
#
# File c:\Users\EfrenTavarez\Documents\Programming\ai-prompt-course\.venv\lib\site-packages\langchain\chains\__init__.py:20
#       1 """**Chains** are easily reusable components linked together.
#       2
#       3 Chains encode a sequence of calls to components like models, document retrievers,
#    (...)
#      17     Chain --> <name>Chain  # Examples: LLMChain, MapReduceChain, RouterChain
#      18 """
# ---> 20 from langchain.chains.api.base import APIChain
#      21 from langchain.chains.api.openapi.chain import OpenAPIEndpointChain
# ...

# %%
os.environ["GROQ_API_KEY"]="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"

llm = ChatGroq(
 model = "llama3-8b-8192"
)

# system_prompt_template = SystemMessagePromptTemplate(
#   template="You are a professional translator."
# )

# prompt_template = PromptTemplate(
#   template="Your task is to translate the following text {text} to {language}."
# )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 4
#       1 import os
#       2 # from langchain.prompts import PromptTemplate, SystemMessagePromptTemplate
#       3 # from langchain.chains import LLMChain
# ----> 4 from langchain_groq import ChatGroq
#       6 os.environ["GROQ_API_KEY"]="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"
#       8 llm = ChatGroq(
#       9  model = "llama3-8b-8192"
#      10 )
#
# File c:\Users\EfrenTavarez\Documents\Programming\ai-prompt-course\.venv\lib\site-packages\langchain_groq\__init__.py:1
# ----> 1 from langchain_groq.chat_models import ChatGroq
#       3 __all__ = ["ChatGroq"]
#
# File c:\Users\EfrenTavarez\Documents\Programming\ai-prompt-course\.venv\lib\site-packages\langchain_groq\chat_models.py:31
#      26 from langchain_core._api import deprecated
#      27 from langchain_core.callbacks import (
# ...
